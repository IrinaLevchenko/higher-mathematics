# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-2, 3, 201)
plt.plot(x, (np.exp(x) + x - 1) / x)
plt.plot(x, x ** 2 - 1)
         
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)

plt.show()
# Out:
# C:\Users\lisat\AppData\Local\Temp/ipykernel_23828/3896922088.py:4: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(x, (np.exp(x) + x - 1) / x)

# %%
from scipy.optimize import fsolve
def equations(p):
    x, y = p
    return (y - x ** 2 + 1, np.exp(x) + x * (1 - y) - 1)

x1, y1 = fsolve(equations, (1, 1))
x2, y2 = fsolve(equations, (-2, 2))

print(f'(x1, y1) = ({x1}, {y1})')
print(f'(x2, y2) = ({x2}, {y2})')
# Out:
# (x1, y1) = (1.0812694402316097e-13, -0.999999999999867)
# (x2, y2) = (-1.5818353528958982, 1.5022030836712916)

# %%
x = np.linspace(-2, 3, 201)
plt.plot(x, (-1 / x) + 2)
plt.plot(x, x ** 2 - 1)
         
plt.xlabel('x')
plt.ylabel('y')
plt.ylim(-5, 5)
plt.grid(True)

plt.show()
# Out:
# C:\Users\lisat\AppData\Local\Temp/ipykernel_23828/2550076497.py:2: RuntimeWarning: divide by zero encountered in true_divide
#   plt.plot(x, (-1 / x) + 2)

# %%
from scipy.optimize import fsolve
def equations(p):
    x, y = p
    return (y - x ** 2 + 1, (-1 / x) + 2 - y)

x1, y1 = fsolve(equations, (2, 2))
x2, y2 = fsolve(equations, (0.5, -0.5))
x3, y3 = fsolve(equations, (-2, 2))

print(f'(x1, y1) = ({x1}, {y1})')
print(f'(x2, y2) = ({x2}, {y2})')
print(f'(x3, y3) = ({x3}, {y3})')
# Out:
# (x1, y1) = (1.5320888862379745, 1.3472963553338761)
# (x2, y2) = (0.3472963553483608, -0.8793852415532005)
# (x3, y3) = (-1.8793852415717716, 2.5320888862379975)
